# %% [markdown]
# # Sentece Similarity Task
# text similarity- different techniques to match query to multiplr sentences and return top 3 matches

# %% [markdown]
# # Using IF-IDF for embedding:
#
# TF- stands for term frequency
# IDF-inverse document frequency
#  TF-IDF is used for information retrieval (IR) from the documents, that can quantify the importance or relevance of string representations (words, phrases, etc)  in a document amongst a collection of documents (corpus).
#
#  TF Folmula: tf(wi, di) = (no of times wi occurs in di / total number of words in di)
#  IDFFolmula: idf(wi,di) = Log(Total Number of documents / No of documents which contains wi word)
#
#  TF-IDF = tf(wi,di) * idf(wi,di)

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from nltk.corpus import stopwords 
from nltk import word_tokenize 
import string
from nltk.stem.porter import PorterStemmer 
import nltk

# %%
"""Download the Punkt tokenizer models """
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\muxair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = [
    "The sky is blue.",
    "I love to code in Python.",
     "Python is most popular language.",
     "Python is best for every one.",
    "The cat chased the mouse.",
    "She sang a beautiful song.",
    "The sun sets in the west.",
    "He enjoys reading books.",
    "The pizza was delicious.",
    "They went for a long walk.",
    "The river flows calmly.",
    "She painted a colorful picture.",
    "The coffee was too hot to drink.",
    "He always wears a hat.",
    "She danced gracefully on stage.",
    "The dog barked loudly.",
    "The flowers bloomed in spring.",
    "They built a sandcastle on the beach.",
    "The mountain peak was covered in snow.",
    "She wrote a heartfelt letter.",
    "The car raced down the highway.",
    "He cooked a gourmet meal.",
    "The rain tapped on the window.",
    "They explored a hidden cave.",
    "She solved the puzzle quickly.",
    "The old tree provided shade.",
    "He fixed the broken bicycle.",
    "The stars twinkled in the night sky.",
    "She studied for the upcoming exam.",
    "The wind rustled the leaves.",
    "He captured the moment with his camera.",
    "She baked cookies in the oven.",
    "The waves crashed against the shore.",
    "He painted a stunning landscape.",
    "She practiced the piano diligently.",
    "The birds chirped in the morning.",
    "He hiked up the steep trail.",
    "She knitted a cozy blanket.",
    "The clock ticked slowly.",
    "He told a funny joke.",
    "She swam in the clear lake.",
    "The candle flickered in the breeze.",
    "He fixed the leaky faucet.",
    "She planted flowers in the garden.",
    "The bus arrived right on time.",
    "He rode his bike to school.",
    "She read a book by the fireplace.",
    "The sunflowers turned towards the sun.",
    "He mowed the lawn on Saturday.",
    "She gazed at the stars.",
    "The chef prepared a gourmet meal.",
    "He played the guitar skillfully.",
    "She greeted everyone with a smile.",
    "The thunder roared in the distance.",
    "He built a birdhouse with his son.",
    "She sang her favorite song.",
    "The leaves fell in autumn.",
    "He helped his neighbor shovel snow.",
    "She wrote in her journal every night.",
    "The airplane soared through the clouds.",
    "He climbed the tall tree.",
    "She sipped tea by the fire.",
    "The children played in the park.",
    "He fixed the broken fence.",
    "She studied the stars with a telescope.",
    "The water in the lake was crystal clear.",
    "He painted a portrait of his friend.",
    "She practiced yoga in the morning.",
    "The river meandered through the valley.",
    "He cooked dinner for his family.",
    "She hiked up the mountain.",
    "The sun set behind the hills.",
    "He planted vegetables in his garden.",
    "She enjoyed the peaceful silence.",
    "The horse galloped across the field.",
    "He played chess with his grandfather.",
    "She wrote a poem about nature.",
    "The wind whispered through the trees.",
    "He fixed the squeaky door.",
    "She danced under the moonlight.",
    "The children built a sandcastle.",
    "He studied ancient history.",
    "She painted a vivid sunset.",
    "The rain tapped gently on the roof.",
    "He cooked breakfast for his family.",
    "She explored a mysterious cave.",
    "The waves crashed on the shore.",
    "He captured the beauty of the ocean.",
    "She baked a batch of chocolate chip cookies.",
    "The mountain peak was covered in mist.",
    "He read a novel by the fireplace.",
    "She watched the sunrise.",
    "The artist painted a masterpiece.",
    "He walked through the forest.",
    "She played the piano with passion.",
    "The birds sang in harmony.",
    "He fixed the broken window.",
    "She wrote a heartfelt letter to her friend.",
    "The river flowed peacefully.",
    "He hiked up a steep hill.",
    "She practiced ballet every day.",
    "The sunflowers bloomed in the garden.",
    "He cooked a delicious meal.",
    "She enjoyed the tranquility of the lake.",
    "The wind rustled the leaves of the trees.",
    "He played catch with his dog.",
    "She painted a mural on the wall.",
    "The waves crashed against the rocks.",
    "He captured the essence of nature in his painting.",
    "She baked a loaf of fresh bread.",
    "The rain stopped and the sun emerged.",
    "He explored a hidden waterfall.",
    "She danced with grace and elegance.",
    "The children built a snowman in the yard.",
    "He read a book under the shade of a tree.",
    "She watched the stars twinkle in the night sky.",
    "The mountain peak was bathed in sunlight.",
    "He climbed to the top of the hill.",
    "She played a soothing melody on the piano.",
    "The birds chirped merrily.",
    "He fixed the leaky roof.",
    "She wrote a love letter to her partner.",
    "The river flowed gently through the valley.",
    "He hiked through the dense forest.",
    "She practiced meditation every morning.",
    "The sunflowers turned to face the sun.",
    "He cooked dinner for his friends.",
    "She enjoyed the serenity of the lake.",
    "The wind whispered secrets to the trees.",
    "He played fetch with his dog at the park.",
    "She painted a breathtaking landscape.",
    "The waves crashed against the shoreline.",
    "He captured the beauty of a sunset.",
    "She baked a batch of oatmeal cookies.",
    "The mountain peak was shrouded in mist.",
    "He read a novel by the candlelight.",
    "She watched the sunrise with awe.",
    "The artist created a stunning masterpiece.",
    "He walked along the riverbank.",
    "She played the piano with precision.",
    "The birds sang a melodious tune.",
    "He fixed the creaky staircase.",
    "She wrote a touching letter to her family.",
    "The river flowed silently.",
    "He hiked up a rugged mountain.",
    "She practiced yoga in the garden.",
    "The sunflowers bloomed brightly.",
    "He cooked a mouthwatering meal.",
    "She found solace by the lake.",
    "The wind rustled the leaves playfully.",
    "He played soccer with his friends.",
    "She painted a mural in the community center.",
    "The waves crashed against the cliffs.",
    "He captured the essence of the ocean.",
    "She baked a loaf of whole wheat bread.",
    "The rain ceased and the sky cleared.",
    "He explored a hidden cave in the hills.",
    "She danced under the stars.",
    "The children built sandcastles on the beach.",
    "He read a book under the shade of an oak tree.",
    "She watched the stars sparkle in the night sky.",
    "The mountain peak was bathed in golden light.",
    "He climbed a steep hill to gain a better view.",
    "She played a soothing lullaby on the piano.",
    "The birds chirped joyfully.",
    "He fixed the rattling windows.",
    "She wrote a heartfelt thank you letter.",
    "The river flowed calmly through the valley.",
    "He hiked through the dense jungle.",
    "She practiced mindfulness by the lake.",
    "The sunflowers faced the sun with devotion.",
    "He cooked a gourmet feast for his guests.",
    "She enjoyed the stillness of the lake.",
    "The wind rustled the leaves gently.",
    "He played frisbee with his dog at the park.",
    "She painted a striking abstract painting.",
    "The waves crashed against the rocky shore.",
    "He captured the beauty of a sunrise.",
    "She baked a batch of peanut butter cookies.",
    "The mountain peak was obscured by mist.",
    "He read a book by the soft glow of a lamp.",
    "She watched the sunrise in awe.",
    "The artist depicted a scene of breathtaking beauty.",
    "He walked along the river's edge.",
    "She played the piano with skillful fingers.",
    "The birds sang in perfect harmony.",
    "He fixed the squeaking door hinge.",
    "She wrote a heartfelt letter to her parents.",
    "The river flowed peacefully through the landscape.",
    "He hiked up a steep mountain trail.",
    "She practiced yoga on a grassy hill.",
    "The sunflowers turned toward the radiant sun.",
    "He cooked a delectable meal for his family.",
    "She found solace by the tranquil lake.",
    "The wind rustled the leaves softly.",
    "He played basketball with his friends.",
    "She painted a beautiful scene on the canvas.",
    "The waves crashed against the shore with intensity.",
    "He captured the vivid colors of a sunset.",
    "She baked a loaf of fresh sourdough bread.",
    "The rain ceased and a rainbow appeared.",
    "He explored a hidden cave in the mountains.",
    "She danced under the moonlit sky.",
    "The children built sandcastles with glee.",
    "He read a book while sitting beneath a tree.",
    "She watched the stars twinkle in the clear night sky.",
    "The mountain peak was bathed in warm sunlight.",
    "He climbed a rocky hill to enjoy the view.",
    "She played a soothing melody on the grand piano.",
    "The birds sang their morning serenade.",
    "He fixed the rattling shutters.",
    "She wrote a heartfelt letter of gratitude.",
    "The river flowed gently through the serene valley.",
    "He hiked through the dense forest with determination.",
    "She practiced meditation in the peaceful garden.",
    "The sunflowers turned their faces toward the sun.",
    "He cooked a gourmet meal for a special occasion.",
    "She enjoyed the tranquility of the lake's waters.",
    "The wind rustled the leaves in a playful dance.",
    "He played catch with his excited puppy.",
    "She painted a masterpiece that captured hearts.",
    "The waves crashed against the rugged shore.",
    "He captured the mesmerizing colors of a sunrise.",
    "She baked a batch of oatmeal raisin cookies.",
    "The mountain peak was shrouded in misty fog.",
    "He read a book with a cup of tea by his side.",
    "She watched the sunrise with wonder.",
    "The artist's canvas displayed a breathtaking scene.",
    "He walked along the river's edge, deep in thought.",
    "She played the piano, filling the room with music.",
    "The birds sang a cheerful melody.",
    "He fixed the loose floorboard in the hallway.",
    "She wrote a heartfelt letter to her best friend.",
    "The river flowed silently through the valley.",
    "He hiked up a steep and rocky path.",
    "She practiced yoga under the morning sun.",
    "The sunflowers stretched toward the radiant sun.",
    "He cooked a mouthwatering feast for his loved ones.",
    "She found tranquility by the calm lake.",
    "The wind rustled the leaves in a gentle breeze.",
    "He played soccer with his friends at the park.",
    "She painted a mural that told a story.",
    "The waves crashed against the shore with power.",
    "He captured the vibrant hues of a sunset.",
    "She baked a loaf of crusty artisan bread.",
    "The rain stopped and gave way to a clear sky.",
    "He explored a hidden cave in the remote mountains.",
    "She danced under the shimmering stars.",
    "The children built sandcastles along the shoreline.",
    "He read a book under the shade of a sprawling tree.",
    "She watched the stars twinkle in the velvet sky.",
    "The mountain peak was illuminated by the rising sun.",
    "He climbed a steep hill, overcoming challenges.",
    "She played a soothing melody on the baby grand piano.",
    "The birds sang in harmony, creating a symphony.",
    "He fixed the squeaky front door.",
    "She wrote a sincere letter of appreciation.",
    "The river flowed gently through the peaceful valley.",
    "He hiked through the dense forest, guided by nature.",
    "She practiced meditation in the serene garden.",
    "The sunflowers turned their faces toward the sun's warmth.",
    "He cooked a gourmet meal to impress his guests.",
    "She enjoyed the serenity of the lake's still waters.",
    "The wind rustled the leaves, creating a soft melody.",
    "He played fetch with his enthusiastic dog.",
    "She painted a masterpiece that evoked emotion.",
    "The waves crashed against the rocky shore relentlessly.",
    "He captured the breathtaking beauty of a sunrise.",
    "She baked a batch of chewy chocolate chip cookies.",
    "The mountain peak was enshrouded in mist and mystery.",
    "He read a book by the gentle light of a lantern.",
    "She watched the sunrise in quiet contemplation.",
    "The artist's canvas displayed a scene of pure enchantment.",
    "He walked along the river, a sense of peace enveloping him.",
    "She played the piano with a depth of emotion.",
    "The birds sang their joyful songs.",
    "He fixed the rattling shutters on a windy day.",
    "She wrote a heartfelt letter to her grandparents.",
    "The river flowed calmly through the tranquil valley.",
    "He hiked up a steep and challenging mountain trail.",
    "She practiced yoga, connecting with her inner self.",
    "The sunflowers turned their faces toward the radiant sunbeams.",
    "He cooked a delectable feast for a special celebration.",
    "She found comfort by the serene lake's edge.",
    "The wind rustled the leaves in a gentle whisper.",
    "He played a spirited game of basketball with his friends.",
    "She painted a mural that told a story of unity.",
    "The waves crashed against the shore, a powerful force.",
    "He captured the brilliant colors of a sunset in his painting.",
    "She baked a loaf of fresh multigrain bread.",
    "The rain ceased and revealed a vibrant rainbow.",
    "He explored a hidden cave, curious and fearless.",
    "She danced under the moon's soft glow.",
    "The children built sandcastles on the sandy beach.",
    "He read a book, engrossed in its pages.",
    "She watched the stars twinkle in the clear night's canvas.",
    "The mountain peak was bathed in warm hues of light.",
    "He climbed a rocky hill, determination in every step.",
    "She played a soothing melody on the grand piano, her heart at peace.",
    "The birds sang their cheerful melodies, nature's orchestra.",
    "He fixed the creaking staircase, bringing quiet back to the house.",
    "She wrote a heartfelt letter to her close friend.",
    "The river flowed serenely through the idyllic valley.",
    "He hiked up a steep and rugged mountain trail.",
    "She practiced yoga in the tranquil garden, finding balance.",
    "The sunflowers turned their faces toward the life-giving sun.",
    "He cooked a gourmet meal to celebrate a special occasion.",
    "She found tranquility by the calm lake's shores.",
    "The wind rustled the leaves, nature's gentle rhythm.",
    "He played fetch with his energetic canine companion.",
    "She painted a mural that told a tale of hope.",
    "The waves crashed against the shore, a dance of water and land.",
    "He captured the stunning beauty of a sunset on his canvas.",
    "She baked a batch of mouthwatering chocolate chunk cookies.",
    "The mountain peak was veiled in mist, an air of mystery.",
    "He read a book beneath the soft glow of a lamp.",
    "She watched the sunrise with wonder and amazement.",
    "The artist's canvas portrayed a scene of pure serenity.",
    "He walked along the riverbank, lost in thought.",
    "She played the piano with passion and emotion.",
    "The birds sang their melodies, a chorus of life.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the verdant valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced yoga, finding inner peace in the garden.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to impress his date.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep mountain trail, embracing the challenge.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog.",
    "She painted a mural that conveyed a sense of belonging.",
    "The waves crashed against the shore, a powerful spectacle.",
    "He captured the vivid colors of a sunset in his art.",
    "She baked a batch of delectable almond butter cookies.",
    "The mountain peak was shrouded in a mystical mist.",
    "He read a book, transported to another world through its pages.",
    "She watched the sunrise with a sense of awe.",
    "The artist's canvas displayed a scene of ethereal beauty.",
    "He walked along the riverbank, finding solace in its flow.",
    "She played the piano with skill and passion.",
    "The birds sang their melodies, a natural symphony.",
    "He fixed the rattling windows, restoring peace to the room.",
    "She wrote a heartfelt letter to her mentor.",
    "The river flowed gently through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the nurturing sun.",
    "He cooked a delectable meal to celebrate a milestone.",
    "She found solace by the serene lake, reflecting on life.",
    "The wind rustled the leaves, a symphony of nature's music.",
    "He played soccer with his friends at the local park.",
    "She painted a mural that told a story of unity and diversity.",
    "The waves crashed against the shore, a rhythmic dance.",
    "He captured the vibrant colors of a sunset in his photography.",
    "She baked a loaf of fresh rosemary-infused bread.",
    "The rain stopped, revealing a vibrant rainbow across the sky.",
    "He explored a hidden cave, venturing into the unknown.",
    "She danced under the moonlight, her spirit free.",
    "The children built sandcastles on the sandy shoreline.",
    "He read a book, immersing himself in its world.",
    "She watched the stars twinkle in the velvety night sky.",
    "The mountain peak was bathed in the soft light of dawn.",
    "He climbed a steep hill, determined to conquer it.",
    "She played a soothing melody on the grand piano, soothing hearts.",
    "The birds sang their harmonious melodies, a natural chorus.",
    "He fixed the creaking floorboards, silencing the noise.",
    "She wrote a heartfelt letter to her dear friend.",
    "The river flowed serenely through the lush valley.",
    "He hiked up a steep and challenging mountainside.",
    "She practiced meditation in the tranquil garden oasis.",
    "The sunflowers turned their faces toward the life-giving sunrays.",
    "He cooked a gourmet meal to celebrate a milestone.",
    "She found tranquility by the serene lake's edge, lost in thought.",
    "The wind rustled the leaves, creating a soothing melody.",
    "He played fetch with his energetic and joyful dog."]

# %%
def sentence_tokenize(sentence):
    return word_tokenize(sentence)

# %%
tokenized_sentences = []
for sentence in sentences:
    sent_tokenize = sentence_tokenize(sentence)
    tokenized_sentences.append(sent_tokenize)

# %%
tokenized_sentences
# Out:
# [['The', 'sky', 'is', 'blue', '.'],
#  ['I', 'love', 'to', 'code', 'in', 'Python', '.'],
#  ['Python', 'is', 'most', 'popular', 'language', '.'],
#  ['Python', 'is', 'best', 'for', 'every', 'one', '.'],
#  ['The', 'cat', 'chased', 'the', 'mouse', '.'],
#  ['She', 'sang', 'a', 'beautiful', 'song', '.'],
#  ['The', 'sun', 'sets', 'in', 'the', 'west', '.'],
#  ['He', 'enjoys', 'reading', 'books', '.'],
#  ['The', 'pizza', 'was', 'delicious', '.'],
#  ['They', 'went', 'for', 'a', 'long', 'walk', '.'],
#  ['The', 'river', 'flows', 'calmly', '.'],
#  ['She', 'painted', 'a', 'colorful', 'picture', '.'],
#  ['The', 'coffee', 'was', 'too', 'hot', 'to', 'drink', '.'],
#  ['He', 'always', 'wears', 'a', 'hat', '.'],
#  ['She', 'danced', 'gracefully', 'on', 'stage', '.'],
#  ['The', 'dog', 'barked', 'loudly', '.'],
#  ['The', 'flowers', 'bloomed', 'in', 'spring', '.'],
#  ['They', 'built', 'a', 'sandcastle', 'on', 'the', 'beach', '.'],
# ...

# %% [markdown]
# # StopWords
# Somewords words in english language like a, an, the, you to his etc to remove these type of words from chunks we are using stopwords.

# %%
"""
this code will print all stopwords avalible in the english language
"""
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'won', 'myself', "she's", 'is', 'at', 'isn', 'shouldn', "hadn't", 'herself', 'should', 'so', 'yourself', 'after', 'we', 'he', 'but', 'can', 'just', 'ours', 'than', 'needn', 'its', 'their', 'him', "it's", 'when', "needn't", 'no', 'll', "couldn't", 'having', 'haven', "you'd", 'against', 'very', 'between', 'then', 'doesn', 'through', 'whom', 'm', 'over', 'himself', "isn't", 'if', 'mustn', "should've", 'o', 'i', 'once', 'for', 'don', 'with', 'on', "hasn't", 'were', 'they', 'y', 'below', 'who', 'didn', "aren't", 'what', 'few', "mustn't", 'shan', "weren't", 've', 'under', 'have', 'our', 'weren', 'by', 'themselves', 'from', 'here', 't', 'that', 'do', "shan't", 'more', 'and', 'couldn', 'hadn', 'or', "wasn't", 'nor', 'not', 'further', 'how', 'to', 'there', 'mightn', 'all', 'was', 'doing', 'aren', 'am', 'does', 'yours', 'during', 'each', 'some', "you'll", "haven't", 'wouldn', 'your', 'such', 'this', 'now', 'hers', 'which', 'other', "doesn't", 'off', "you've", 'while', 'into', 'in', 'd', 'same
# ...

# %% [markdown]
# # Remove Stopwords and punctuations from text

# %%
porter_stemmer = PorterStemmer()

def remove_stopwords_and_punctuations(sentence):

    sent = []
    for word in sentence:
        if word not in stop_words and word not in string.punctuation:
            stemming_word = porter_stemmer.stem(word)
            sent.append(stemming_word)
    return sent

# %%
def preprocess_data():
    filtered_sentence = []

    for sentence in tokenized_sentences:
        sent = remove_stopwords_and_punctuations(sentence)
        filtered_sentence.append(sent)
    
    return filtered_sentence

# %%
filtered_sentence = preprocess_data()

# %%
filtered_sentence
# Out:
# [['the', 'sky', 'blue'],
#  ['i', 'love', 'code', 'python'],
#  ['python', 'popular', 'languag'],
#  ['python', 'best', 'everi', 'one'],
#  ['the', 'cat', 'chase', 'mous'],
#  ['she', 'sang', 'beauti', 'song'],
#  ['the', 'sun', 'set', 'west'],
#  ['he', 'enjoy', 'read', 'book'],
#  ['the', 'pizza', 'delici'],
#  ['they', 'went', 'long', 'walk'],
#  ['the', 'river', 'flow', 'calmli'],
#  ['she', 'paint', 'color', 'pictur'],
#  ['the', 'coffe', 'hot', 'drink'],
#  ['he', 'alway', 'wear', 'hat'],
#  ['she', 'danc', 'grace', 'stage'],
#  ['the', 'dog', 'bark', 'loudli'],
#  ['the', 'flower', 'bloom', 'spring'],
#  ['they', 'built', 'sandcastl', 'beach'],
#  ['the', 'mountain', 'peak', 'cover', 'snow'],
#  ['she', 'wrote', 'heartfelt', 'letter'],
#  ['the', 'car', 'race', 'highway'],
#  ['he', 'cook', 'gourmet', 'meal'],
#  ['the', 'rain', 'tap', 'window'],
#  ['they', 'explor', 'hidden', 'cave'],
#  ['she', 'solv', 'puzzl', 'quickli'],
#  ['the', 'old', 'tree', 'provid', 'shade'],
# ...

# %% [markdown]
# # Convert Text to Vectors
# ## Use TFIDF:
#  It's a numerical representation that helps to reflect the significance of a term in a specific document relative to the entire corpus of documents.
#  ### Why IFIDF:
#      1) Give Term Importance
#      2)  TF-IDF can be used to calculate the similarity between documents.
#      3) Simple and easy to use

# %%
tfidf_vectorizer = TfidfVectorizer()
sentences = [' '.join(tokens) for tokens in tokenized_sentences]
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)

# %%
query = "python is my favorte language."
tokenize_query = sentence_tokenize(query)
filter_query  = remove_stopwords_and_punctuations(tokenize_query)
query_tfidf = tfidf_vectorizer.transform(filter_query)

# %% [markdown]
# # Time Complexity of TFIDF
#     TFIDF Time complexity: TF = O(NxD), IDF = O(V)
#     TFIDF = O(NxDxV)
#     N -> Number of total dcuments.
#     D ->  the average document length.
#     V ->  the vocabulary size(uniqe words).

# %% [markdown]
# # Cosine Similarity

# %%
cosine_similarities = cosine_similarity(query_tfidf, tfidf_matrix)[0]

# %% [markdown]
# # Time complexity of Cosine Similarity:
#     time complixity of cosine similarity is O(n) -> Linear
#     Space complexity of cosine similarity is O(n) -> Linear

# %%
"""Calcualte time complexity of cosine similairty."""
import time
start_time = time.time()
similarities = cosine_similarity(query_tfidf, tfidf_matrix)[0]
end_time = time.time()
total_time = end_time- start_time
print("Time complexity of cosine similarity is : ",total_time, " seconds")
# Out:
# Time complexity of cosine similarity is :  0.0  seconds

# %%
"""Get top 3 similar sentences from the whole document. """

top_n_similar_sentences = 3

similar_indices = np.argsort(cosine_similarities)[-top_n_similar_sentences:][::-1]


print("Query:", query)
print("Most similar sentences:")
for idx in similar_indices:
    print(sentences[idx])
# Out:
# Query: python is my favorte language.
# Most similar sentences:
# I love to code in Python .
# Python is most popular language .
# Python is best for every one .

# %% [markdown]
# # Lets Try Manhatan Distance
#        Manhattan distance is calculated as the sum of the absolute differences between the two vectors.
#        Formula :Σ|v1[i] – v2[i]|

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
manhattan_distances = pairwise_distances(query_tfidf, tfidf_matrix, metric='l1')

# %%
similar_indices = np.argsort(manhattan_distances[0])[:top_n_similar_sentences]

# similar_sentences = [sentences[i] for i in similar_indices]

# %% [markdown]
# # Output

# %%
print("Query:", query)
print("Most similar sentences:")
for idx in similar_indices:
    print(sentences[idx])
# Out:
# Query: python is my favorte language.
# Most similar sentences:
# I love to code in Python .
# Python is most popular language .
# Python is best for every one .

# %% [markdown]
# # Time and Space Complexity
#     Time complexity of manhatan distance: O(n)
#     Space complexity of manhatan distance O(n)

# %%
"""Calcualte time complexity of Manhatan distance."""
import time
start_time = time.time()
manhattan_distances = pairwise_distances(query_tfidf, tfidf_matrix, metric='l1')
end_time = time.time()
total_time = end_time- start_time
print("Time complexity of cosine similarity is : ",total_time, " seconds")
# Out:
# Time complexity of cosine similarity is :  0.0  seconds

# %% [markdown]
# # Conclusion
# for both cosine similarity and manhatan taking same time to find the similarity between vectors
